# %% [markdown]
# ## Get the list of characters; their aliases; their books of appearance
# ### get the list of characters from the wiki awoif
# We extract all links to character's page from teh wiki and get all pages.
# Save all HTML for further analysis

# %%
import requests
from bs4 import BeautifulSoup

# requests to the 
r = requests.get('https://awoiaf.westeros.org/index.php/List_of_characters')
soup = BeautifulSoup(r.text)

# extract all anchors (links) tags: 'a'
links = soup.find_all('a')
pages = []
for link in links:
    S1 = set(['title','href'])
    S2 = set(link.attrs.keys())
    if S1 == S2:
        pages.append((link['href'],link['href'].split('/')[-1]))

pages = pages[:-5] # remove last 5 as they are irrelevant
pages = set(pages) # create a set to remove duplicates

# for each link, download the page and store on disk
for href,name in pages:
    r = requests.get('https://awoiaf.westeros.org' + href)
    with open(name+'.html','w+', encoding='utf-8') as fp:
        fp.write(r.text)
# Out:
# /index.php/Aegon_V_Targaryen

# %% [markdown]
# ### analysis of html page: getCharacterDict
# We are after several informations:
# * Short name (title of the infobox)
# * common name (title of the page)
# * full name (field fo the infobox)
# * aliases (field of the infobox)
# * book list (field of the infobox)
#
# if no infobox was found, discard the character

# %%
books_vol = {
    'A Game of Thrones':1,
    'A Clash of Kings':2,
    'A Storm of Swords':3,
    'A Feast for Crows':4,
    'A Dance with Dragons':5
}


def getCharacterDict(soup):
    fullname = None
    aliases = None
    books = None
    
    try:
        short_name = soup.find("table", class_="infobox").caption.text.strip()
    except:
        short_name = None
    
    try:
        common_name = soup.find('h1', class_='firstHeading').text.strip()
    except:
        common_name = None        

    try:
        tbody = soup.find("table", class_="infobox").tbody
        rows = tbody.find_all("tr")

        for row in rows:
            for child in row.children:
                if child.name == 'th':
                    if row.th.text.lower()=='full name':
                        fullname = row.td.text.strip()

                    if row.th.text.lower()=='alias':
                        raw_alias = row.td.text
                        regex = r"(\s?\[[0-9]+\])"
                        subst = ''
                        remove_ref_aliases = re.sub(regex, subst, raw_alias)
                        # detect aliases separation
                        regex = r"([a-z])([A-Z])"
                        subst = "\\1, \\2"
                        normalized_alias = re.sub(regex, subst, remove_ref_aliases)
                        # recreate an array with the aliases
                        aliases = [t.strip() for t in normalized_alias.split(',')]

                    if row.th.text.lower() == 'book(s)':
                        raw_books = row.td.text
                        regex = r"(\s\([a-zA-Z]+\))"
                        subst = ''
                        remove_parenthesis_books = re.sub(regex, subst, raw_books)
                        regex = r"([a-z])([A-Z])"
                        subst = "\\1, \\2"
                        normalized_books = re.sub(regex, subst, remove_parenthesis_books)
                        books = [books_vol[b.strip()] for b in normalized_books.split(',') if b.strip() in books_vol.keys()]
    except:
        return None
    return {'short_name':short_name, 'common_name':common_name, 'fullname':fullname, 'aliases':aliases, 'books':books}

# %% [markdown]
# ### get internal links
# for graph creation purposes

# %%
def getCharacterLinks(soup,names):
    cLinks = []
    links = soup.find_all('a')
    for link in links:
        if 'href' in link.attrs.keys():
            name = link['href'].split('/')[-1]
            if name in names:
                cLinks.append(name)
    return cLinks

# %%
from bs4 import BeautifulSoup
import os
import re

characters = []
characters_links = []
names = []
for root, dirs, files in os.walk('data/html'):
    for name in files:
        if name.endswith('.html'):
            names.append(name[:-5])

    for name in files:
        if name.endswith('.html'):
            with open(os.path.join(root, name),'r') as fp:
                html = fp.read()
                soup = BeautifulSoup(html,'lxml')
                character = getCharacterDict(soup)
                if character is not None:
                    character['url'] = name[:-5]
                    characters.append(character)
                    character_links = {name[:-5]:getCharacterLinks(soup,names)}
                    characters_links.append(character_links)
print(characters)
# Out:
# [{'short_name': 'Sumner Crakehall', 'common_name': 'Sumner Crakehall', 'fullname': None, 'aliases': None, 'books': [3, 4], 'url': 'Sumner_Crakehall'}, {'short_name': None, 'common_name': 'Lamprey', 'fullname': None, 'aliases': ['Lamprey'], 'books': [3], 'url': 'Lamprey'}, {'short_name': 'Rhaego', 'common_name': 'Rhaego', 'fullname': None, 'aliases': ['The stallion who mounts the world'], 'books': [1, 2, 3, 4], 'url': 'Rhaego'}, {'short_name': 'Jeyne Waters', 'common_name': 'Jeyne Waters', 'fullname': None, 'aliases': None, 'books': [], 'url': 'Jeyne_Waters'}, {'short_name': 'Sybell Spicer', 'common_name': 'Sybell Spicer', 'fullname': None, 'aliases': None, 'books': [3, 4], 'url': 'Sybell_Spicer'}, {'short_name': 'Dennett', 'common_name': 'Dennet', 'fullname': None, 'aliases': None, 'books': [3], 'url': 'Dennet'}, {'short_name': 'Lord Ashford', 'common_name': 'Lord Ashford', 'fullname': None, 'aliases': None, 'books': [], 'url': 'Lord_Ashford'}, {'short_name': 'Selyse Florent', 'common_name': 'Selyse Florent', 'fullname': None, 'aliases': None, 'books': [1, 2, 3, 4, 5], 'url': 'Selyse_Florent'}, {'short_name': 'Humfrey Beesbury', 'common_name': 'Humfrey Beesbury', 'fullname': None, 'aliases': None, 'books': [], 'url': 'Humfrey_Beesbury'}, {'short_name': 'Jayde', 'common_name': 'Jayde', 'fullname': None, 'aliases': None, 'books': [3], 'url': 'Jayde'}, {'short_name': 'Robin Hollard', 'common_name': 'Robin Hollard', 'fullname': None, 'aliases': None, 'books': [4], 'url': 'Robin_Hollard'}, {'short_name': 'Dunaver', 'common_name': 'Dunaver', 'fullname': None, 'aliases': None, 'books': [2], 'url': 'Dunaver'}, {'short_name': 'Esgred', 'common_name': 'Esgred', 'fullname': None, 'aliases': None, 'books': [2], 'url': 'Esgred'}, {'short_name': 'Lewyn Martell', 'common_name': 'Lewyn Martell', 'fullname': None, 'aliases': None, 'books': [1, 3, 4, 5], 'url': 'Lewyn_Martell'}, {'short_name': 'Samwell Spicer', 'common_name': 'Samwell Spicer', 'fullname': None, 'aliases': None, 'books': [3, 4], 'url': 'Samwell_Spicer'}, {'short_name': 'Kella', 'common_name': 'Kella', 'fullname': None, 'aliases': None, 'books': [3], 'url': 'Kella'}, {'short_name': 'Gormon Peake', 'common_name': 'Gormon Peake', 'fullname': None, 'aliases': ['Gormy'], 'books': [], 'url': 'Gormon_Peake'}, {'short_name': 'Godry Farring', 'common_name': 'Godry Farring', 'fullname': None, 'aliases': ['Godry the Giantslayer'], 'books': [4, 5], 'url': 'Godry_Farring'}, {'short_name': 'Wyl', 'common_name': 'Wyl (guard)', 'fullname': None, 'aliases': None, 'books': [1], 'url': 'Wyl_(guard)'}, {'short_name': 'Ollo', 'common_name': 'Ollo Lophand', 'fullname': None, 'aliases': ['Ollo Lophand'], 'books': [3, 4, 5], 'url': 'Ollo_Lophand'}, {'short_name': 'Ferrego Antaryon', 'common_name': 'Ferrego Antaryon', 'fullname': None, 'aliases': None, 'books': [4, 5], 'url': 'Ferrego_Antaryon'}, {'short_name': 'Anders Yronwood', 'common_name': 'Anders Yronwood', 'fullname': None, 'aliases': None, 'books': [3, 4, 5], 'url': 'Anders_Yronwood'}, {'short_name': 'Lomas Estermont', 'common_name': 'Lomas Estermont', 'fullname': None, 'aliases': None, 'books': [2, 3, 4, 5], 'url': 'Lomas_Estermont'}, {'short_name': 'Hoke', 'common_name': 'Hoke', 'fullname': None, 'aliases': ['Hoke the Horseleg'], 'books': [4], 'url': 'Hoke'}, {'short_name': 'Edwyd Fossoway', 'common_name': 'Edwyd Fossoway', 'fullname': None, 'aliases': None, 'books': [2], 'url': 'Edwyd_Fossoway'}, {'short_name': 'Leyla Hightower', 'common_name': 'Leyla Hightower', 'fullname': None, 'aliases': None, 'books': [4], 'url': 'Leyla_Hightower'}, {'short_name': 'Hugo Wull', 'common_name': 'Hugo Wull', 'fullname': None, 'aliases': ['Big Bucket', 'Big Bucket Wull'], 'books': [4, 5], 'url': 'Hugo_Wull'}, {'short_name': 'Terrence Kenning', 'common_name': 'Terrence Kenning', 'fullname': None, 'aliases': None, 'books': [3, 4, 5], 'url': 'Terrence_Kenning'}, {'short_name': 'Walton Frey', 'common_name': 'Walton Frey', 'fullname': None, 'aliases': None, 'books ...

# %%
print(characters_links)
# Out:
# [{'Sumner_Crakehall': ['Sumner_Crakehall', 'Aerys_II_Targaryen', 'Jaime_Lannister', 'Merrett_Frey', 'Kingswood_Brotherhood', 'Wenda']}, {'Lamprey': ['Dragonstone', 'Davos_Seaworth']}, {'Rhaego': ['House_Targaryen', 'Daenerys_Targaryen', 'Drogo', 'Drogo', 'Mirri_Maz_Duur', 'Daenerys_Targaryen', 'Mirri_Maz_Duur', 'Mirri_Maz_Duur', 'Jorah_Mormont', 'Mirri_Maz_Duur', 'Daenerys_Targaryen', 'Aegon_V_Targaryen', 'Duncan_Targaryen', 'Jaehaerys_II_Targaryen', 'Rhaelle_Targaryen', 'Aerys_II_Targaryen', 'Rhaella_Targaryen', 'House_Baratheon', 'Rhaegar_Targaryen', 'Elia_Martell', 'Drogo', 'Daenerys_Targaryen', 'Hizdahr_zo_Loraq', 'Rhaenys_Targaryen_(daughter_of_Rhaegar)', 'Aegon_Targaryen_(son_of_Rhaegar)', 'Viserys_Targaryen']}, {'Jeyne_Waters': ['Alyn_Velaryon', 'Elaena_Targaryen', 'Alyn_Velaryon', 'Elaena_Targaryen', 'Jon_Waters', 'Daemon_Targaryen', 'Laena_Velaryon', 'Laenor_Velaryon', 'Rhaenyra_Targaryen', 'Daemon_Targaryen', 'Addam_Velaryon', 'Aegon_III_Targaryen', 'Rhaena_Targaryen_(daughter_of_Daemon)', 'Baela_Targaryen', 'Alyn_Velaryon', 'Elaena_Targaryen', 'Jon_Waters', 'Daemon_Targaryen', 'Rhea_Royce', 'Laena_Velaryon', 'Rhaenyra_Targaryen']}, {'Sybell_Spicer': ['Sybell_Spicer', 'Gawen_Westerling', 'Gawen_Westerling', 'Robb_Stark', 'Westerlands', 'Riverrun', 'Jeyne_Westerling', 'Eleyna_Westerling', 'Rollam_Westerling', 'Edmure_Tully', 'Jaime_Lannister', 'Casterly_Rock', 'Joy_Hill', 'Gerion_Lannister', 'Rolph_Spicer', 'Raynald_Westerling', 'Rolph_Spicer', 'Gawen_Westerling', 'Raynald_Westerling', 'Jeyne_Westerling', 'Robb_Stark', 'Eleyna_Westerling', 'Rollam_Westerling']}, {'Dennet': ['Brotherhood_without_banners', 'Brotherhood_without_banners', 'Sandor_Clegane', 'Beric_Dondarrion', 'Anguy', 'Kyle']}, {'Lord_Ashford': ['The_Hedge_Knight', 'Daeron_II_Targaryen', 'Androw_Ashford', 'Robert_Ashford', 'Tourney_at_Ashford_Meadow', 'Hand_of_the_King', 'Baelor_Targaryen_(son_of_Daeron_II)', 'The_Hedge_Knight']}, {'Selyse_Florent': ['Selyse_Florent', 'Stannis_Baratheon', 'Stannis_Baratheon', 'Dragonstone', 'R%27hllor', 'Melisandre', 'Stannis_Baratheon', 'Shireen_Baratheon', 'Delena_Florent', 'Edric_Storm', 'Shireen_Baratheon', 'Varys', 'Melisandre', 'R%27hllor', 'Axell_Florent', 'Joffrey_Baratheon', 'Shireen_Baratheon', 'Patchface', 'Storm%27s_End', 'Axell_Florent', 'Renly_Baratheon', 'Imry_Florent', 'Dragonstone', 'Alester_Florent', 'Hand_of_the_King', 'Edric_Storm', 'Davos_Seaworth', 'Night%27s_Watch', 'Eastwatch-by-the-Sea', 'Castle_Black', 'Eastwatch-by-the-Sea', 'Cotter_Pyke', 'Patchface', 'Jon_Snow', 'Gerrick_Kingsblood', 'Axell_Florent', 'Raymun_Redbeard', 'King-Beyond-the-Wall', 'Tormund', 'Val', 'Stannis_Baratheon', 'R%27hllor', 'Delena_Florent', 'Stannis_Baratheon', 'Edric_Storm', 'Jon_Snow', 'Jon_Snow', 'Melisandre', 'Seven_Kingdoms', 'R%27hllor', 'Cressen', 'Petyr_Baelish', 'Pycelle', 'Stannis_Baratheon', 'Melisandre', 'Jon_Snow', 'Val', 'Jon_Snow', 'Jon_Snow', 'Tormund', 'Jon_Snow', 'Alester_Florent', 'Melara_Crane', 'Axell_Florent', 'Ryam_Florent', 'Colin_Florent', 'Rylene_Florent', 'Rycherd_Crane', 'Randyll_Tarly', 'Melessa_Florent', 'Alekyne_Florent', 'Rhea_Florent', 'Leyton_Hightower', 'Stannis_Baratheon', 'Imry_Florent', 'Erren_Florent', 'Hosman_Norcross', 'Delena_Florent', 'Omer_Florent', 'Merrell_Florent', 'Samwell_Tarly', 'Talla_Tarly', 'Dickon_Tarly', 'Shireen_Baratheon', 'Alester_Norcross', 'Renly_Norcross', 'Edric_Storm', 'House_Targaryen', 'Visenya_Targaryen', 'Rhaenys_Targaryen', 'Jeyne_Westerling_(wife_of_Maegor_I)', 'Alysanne_Targaryen', 'Aemma_Arryn', 'Alicent_Hightower', 'Helaena_Targaryen', 'Jaehaera_Targaryen', 'Daena_Targaryen', 'Naerys_Targaryen', 'Aelinor_Penrose', 'Rhaella_Targaryen', 'Daemon_Targaryen', 'Drogo', 'Hizdahr_zo_Loraq', 'House_Baratheon', 'Cersei_Lannister', 'Margaery_Tyrell', 'Margaery_Tyrell', 'Alannys_Harlaw', 'House_Stark', 'Jeyne_Westerling']}, {'Humfrey_Beesbury': ['Humfrey_Beesbury', 'Knight', 'The_Hedge_Knight', 'Knight', 'Daeron_II_Targaryen', 'Humfrey_Hardyng', 'Tourney_at_Ashfor ...
